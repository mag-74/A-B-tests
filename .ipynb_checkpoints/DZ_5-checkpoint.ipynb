# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Задание №1
# Вы провели эксперимент c упрощением формы заказа в магазине "Утконос" и получили результаты по метрике конверсий в покупку. Выберите метод оценки и оцените есть ли статистически значимые различия между конверсиями в двух группах при alpha = 5%. Дайте краткие рекомендации команде.
#
# Результаты:
#
# 1) Число юзеров в группах, которые заходили на сайт в период эксперимента: n1 = 15550 и n2 = 15550.
#
# 2) Число юзеров в группах, которые совершили хотя бы одну покупку за период эксперимента: n1 = 164 и n2 = 228
#
# 3) Конверсии: conv1 = 1.05%, conv2 = 1.47%.

# %%
# Из условия задачи знаем:
alpha = 0.05
n1 = 15550
n2 = 15550
n1_buy = 164
n2_buy = 228
conv1 = 0.0105
conv2 = 0.0147

# %% [markdown]
# Мда, попытка решить на питоне провалена. Хотел оценить распределение на нормальность или проверить равенство дисперсий - но для этого нет данных. Скорее всего нужно было по сложному пути использовать непараметрический критерий Уилкоксона... Бог его знает, как решать. Но по ссылке из материалов семинара есть ссылка на онлайн-калькулятор. А в интернете такую задачу рекомендовано решать через хи-квадрат.

# %% [markdown]
# https://www.evanmiller.org/ab-testing/chi-squared.html
# <img src='dz_5_pict.jpg'>

# %% [markdown]
# Делаю вывод, что статистически значимые различия есть. Рекомендация - использовать вторую форму заказа на сайте.

# %% [markdown]
# # Задание №2
# Сравниваем метрику конверсия в покупку. Размер выборки - 10000 элементов в каждой группе . Какой статистический критерий тут лучше всего подойдёт и почему?
#
# Дополнение с семинара: принимаем количество групп равным 2, а само распределение считаем нормальным.

# %% [markdown]
# Если распределение нормальное, то нужно применять параметрические тесты проверки гипотезы, t- или z-критерии. Выбор между ними зависит от факта известна ли нам сигма генеральной совокупности. Допущу, что известна ввиду того, что размер выборки большой и эта не выборка, а ген. совокупность (для больших магазинов спорно конечно ...). Итого z-критерий.
